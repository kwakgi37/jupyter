# %% [markdown]
# # 11/5 ~ 11/11 실습

# %% [markdown]
# ## HSV를 이용한 녹색 비율 구하는 프로그램

# %% [markdown]
# #### 1. 녹색 비율 구하는 프로그램

# %%
import cv2
import numpy as np

# 이미지 파일을 읽어옵니다.
image = cv2.imread('test3.jpg')

# 이미지를 HSV로 변환합니다.
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# 녹색 식물 영역을 분리합니다.
lower_green = np.array([35, 40, 40])
upper_green = np.array([85, 255, 255])
green_mask = cv2.inRange(hsv_image, lower_green, upper_green)

# 녹색 영역에서 녹색 픽셀 수를 측정합니다.
green_pixels = np.count_nonzero(green_mask)

# 전체 픽셀 수를 계산합니다.
total_pixels = image.shape[0] * image.shape[1]

# 녹색 비율을 계산합니다.
green_ratio = green_pixels / total_pixels
print("식물 영역의 녹색 비율: {:.2%}".format(green_ratio))
# Out:
# 식물 영역의 녹색 비율: 0.81%

# %% [markdown]
# # 11/12 ~ 11/18 실습

# %% [markdown]
# #### 2. 연한 녹색 부분도 감지하게 함

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 이미지 파일을 읽어옵니다.
image = cv2.imread('test3.jpg')

# 이미지를 HSV로 변환합니다.
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# 녹색 식물 영역을 분리합니다.
lower_green = np.array([30, 30, 30])  # 하한값을 조정
upper_green = np.array([90, 255, 255])  # 상한값을 조정
green_mask = cv2.inRange(hsv_image, lower_green, upper_green)

# 녹색 영역에서 녹색 픽셀 수를 측정합니다.
green_pixels = np.count_nonzero(green_mask)

# 전체 픽셀 수를 계산합니다.
total_pixels = image.shape[0] * image.shape[1]

# 녹색 비율을 계산합니다.
green_ratio = green_pixels / total_pixels
print("식물 영역의 녹색 비율: {:.2%}".format(green_ratio))

# 시각화를 위해 녹색 마스크를 원본 이미지에 오버레이합니다.
result_image = image.copy()
result_image[green_mask != 0] = [0, 255, 0]  # Green color for the detected regions

# 원본 이미지와 녹색 마스크가 적용된 결과 이미지를 표시합니다.
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.title('Detected Green Regions')

plt.show()
# Out:
# 식물 영역의 녹색 비율: 2.18%

# %% [markdown]
# #### 3. GUI 이미지으로 출력

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 이미지 파일을 읽어옵니다.
image = cv2.imread('test3.jpg')

# 이미지를 HSV로 변환합니다.
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# 녹색 식물 영역을 분리합니다.
lower_green = np.array([30, 30, 30])  # 하한값을 조정
upper_green = np.array([90, 255, 255])  # 상한값을 조정
green_mask = cv2.inRange(hsv_image, lower_green, upper_green)

# 녹색 영역에서 녹색 픽셀 수를 측정합니다.
green_pixels = np.count_nonzero(green_mask)

# 전체 픽셀 수를 계산합니다.
total_pixels = image.shape[0] * image.shape[1]

# 녹색 비율을 계산합니다.
green_ratio = green_pixels / total_pixels
print("식물 영역의 녹색 비율: {:.2%}".format(green_ratio))

# 시각화를 위해 녹색 마스크를 원본 이미지에 오버레이합니다.
result_image = image.copy()
result_image[green_mask != 0] = [0, 255, 0]  # Green color for the detected regions

# 원본 이미지와 녹색 마스크가 적용된 결과 이미지를 표시합니다.
cv2.imshow('orignal', image)
cv2.imshow('Detected_Green_Regions', result_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 식물 영역의 녹색 비율: 2.18%

# %% [markdown]
# #### 4. 녹색 비율의 픽셀 수 구함

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 이미지 파일을 읽어옵니다.
image = cv2.imread('test3.jpg')

# 이미지를 HSV로 변환합니다.
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# 녹색 식물 영역을 분리합니다.
lower_green = np.array([30, 30, 30])  # 하한값을 조정
upper_green = np.array([90, 255, 255])  # 상한값을 조정
green_mask = cv2.inRange(hsv_image, lower_green, upper_green)

# 녹색 영역에서 녹색 픽셀 수를 측정합니다.
green_pixels = np.count_nonzero(green_mask)

# 전체 픽셀 수를 계산합니다.
total_pixels = image.shape[0] * image.shape[1]

# 녹색 비율을 계산합니다.
green_ratio = green_pixels / total_pixels

# 녹색 픽셀 수를 출력합니다.
print("이미지 전체 픽셀 수: ", total_pixels)
print("식물 영역의 녹색 픽셀 수:", green_pixels)

# 녹색 비율을 출력합니다.
print("식물 영역의 녹색 비율: {:.2%}".format(green_ratio))

# 시각화를 위해 녹색 마스크를 원본 이미지에 오버레이합니다.
result_image = image.copy()
result_image[green_mask != 0] = [0, 255, 0]  # Green color for the detected regions

# 원본 이미지와 녹색 마스크가 적용된 결과 이미지를 표시합니다.
cv2.imshow('original', image)
cv2.imshow('Detected_Green_Regions', result_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 이미지 전체 픽셀 수:  252280
# 식물 영역의 녹색 픽셀 수: 5498
# 식물 영역의 녹색 비율: 2.18%

# %% [markdown]
# ## 녹색 영역에 들어가 있을 때 GUI 이미지상에 1이 뜨게 출력

# %%
import cv2
import numpy as np

# 커서 아래의 픽셀의 HSV 값을 가져오기 위한 콜백 함수
def get_hsv_values(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        # 커서 아래 픽셀의 HSV 값을 가져옵니다.
        hsv_values = hsv_image[y, x]
        # 값이 지정된 범위 내에 있는지 확인합니다.
        is_within_range = (lower_green <= hsv_values) & (hsv_values <= upper_green)
        result = 1 if np.all(is_within_range) else 0
        # 결과를 이미지에 표시합니다.
        result_image = image.copy()
        result_image[green_mask != 0] = [0, 255, 0]  # 감지된 영역에 녹색 색상 적용
        cv2.putText(result_image, str(result), (image.shape[1] - 30, image.shape[0] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        # 이미지를 표시합니다.
        cv2.imshow('Detected_Green_Regions', result_image)

# 이미지 파일을 읽어옵니다.
image = cv2.imread('test3.jpg')

# 이미지를 HSV로 변환합니다.
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# 녹색 식물 영역을 분리합니다.
lower_green = np.array([30, 30, 30])  # 하한값을 조정
upper_green = np.array([90, 255, 255])  # 상한값을 조정
green_mask = cv2.inRange(hsv_image, lower_green, upper_green)


# 창과 콜백을 설정합니다.
cv2.namedWindow('Detected_Green_Regions')
cv2.setMouseCallback('Detected_Green_Regions', get_hsv_values)

# 초기 결과 이미지를 표시합니다.
result_image = image.copy()
result_image[green_mask != 0] = [0, 255, 0]  # 감지된 영역에 녹색 색상 적용
cv2.imshow('Detected_Green_Regions', result_image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 위의 내용들을 결합

# %%
import cv2
import numpy as np

# 커서 아래의 픽셀의 HSV 값을 가져오기 위한 콜백 함수
def get_hsv_values(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        # 커서 아래 픽셀의 HSV 값을 가져옵니다.
        hsv_values = hsv_image[y, x]
        # 값이 지정된 범위 내에 있는지 확인합니다.
        is_within_range = (lower_green <= hsv_values) & (hsv_values <= upper_green)
        result = 1 if np.all(is_within_range) else 0
        # 결과를 이미지에 표시합니다.
        result_image = image.copy()
        result_image[green_mask != 0] = [0, 255, 0]  # 감지된 영역에 녹색 색상 적용
        cv2.putText(result_image, str(result), (image.shape[1] - 30, image.shape[0] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        # 이미지를 표시합니다.
        cv2.imshow('Detected_Green_Regions', result_image)

# 이미지 파일을 읽어옵니다.
image = cv2.imread('test3.jpg')

# 이미지를 HSV로 변환합니다.
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# 녹색 식물 영역을 분리합니다.
lower_green = np.array([30, 30, 30])  # 하한값을 조정
upper_green = np.array([90, 255, 255])  # 상한값을 조정
green_mask = cv2.inRange(hsv_image, lower_green, upper_green)

# 녹색 영역에서 녹색 픽셀 수를 측정합니다.
green_pixels = np.count_nonzero(green_mask)

# 전체 픽셀 수를 계산합니다.
total_pixels = image.shape[0] * image.shape[1]

# 녹색 비율을 계산합니다.
green_ratio = green_pixels / total_pixels

# 녹색 픽셀 수를 출력합니다.
print("이미지 전체 픽셀 수: ", total_pixels)
print("식물 영역의 녹색 픽셀 수:", green_pixels)

# 녹색 비율을 출력합니다.
print("식물 영역의 녹색 비율: {:.2%}".format(green_ratio))

# 창과 콜백을 설정합니다.
cv2.namedWindow('Detected_Green_Regions')
cv2.setMouseCallback('Detected_Green_Regions', get_hsv_values)

# 초기 결과 이미지를 표시합니다.
result_image = image.copy()
result_image[green_mask != 0] = [0, 255, 0]  # 감지된 영역에 녹색 색상 적용
cv2.imshow('Detected_Green_Regions', result_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 이미지 전체 픽셀 수:  252280
# 식물 영역의 녹색 픽셀 수: 5498
# 식물 영역의 녹색 비율: 2.18%

# %%
import matplotlib.pyplot as plt

# 콜백 함수 정의
def on_click(event):
    if event.button == 1:  # 왼쪽 버튼 클릭
        x, y = event.xdata, event.ydata
        print(f"마우스 클릭 좌표: x={x}, y={y}")

# 이미지 파일을 읽어옵니다.
image = plt.imread('test3.jpg')

# 이미지를 표시합니다.
fig, ax = plt.subplots()
ax.imshow(image)

# 마우스 클릭 이벤트에 대한 콜백 함수 연결
fig.canvas.mpl_connect('button_press_event', on_click)

# 창을 표시합니다.
plt.show()

# %% [markdown]
# ## 이미지창 띄우고 사라지면 시각화 이미지 띄운 프로그램

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_qt5agg import FigureCanvasQTAgg as FigureCanvas
from matplotlib.figure import Figure

# OpenCV 코드 유지
def get_hsv_values(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        hsv_values = hsv_image[y, x]
        is_within_range = (lower_green <= hsv_values) & (hsv_values <= upper_green)
        result = 1 if np.all(is_within_range) else 0
        result_image = image.copy()
        result_image[green_mask != 0] = [0, 255, 0]
        cv2.putText(result_image, str(result), (image.shape[1] - 30, image.shape[0] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        cv2.imshow('Detected_Green_Regions', result_image)

# 이미지 읽기
image = cv2.imread('test3.jpg')
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
lower_green = np.array([30, 30, 30])
upper_green = np.array([90, 255, 255])
green_mask = cv2.inRange(hsv_image, lower_green, upper_green)
green_pixels = np.count_nonzero(green_mask)
total_pixels = image.shape[0] * image.shape[1]
green_ratio = green_pixels / total_pixels

# OpenCV 창과 콜백 설정
cv2.namedWindow('Detected_Green_Regions')
cv2.setMouseCallback('Detected_Green_Regions', get_hsv_values)

# 초기 결과 이미지 표시
result_image = image.copy()
result_image[green_mask != 0] = [0, 255, 0]
cv2.imshow('Detected_Green_Regions', result_image)

# Matplotlib 시각화
fig, ax = plt.subplots()
ax.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))  # 수정된 부분

cv2.waitKey(0)
cv2.destroyAllWindows()
plt.show()
